# %% [markdown]
# # VL 2 — Schleifen
#
# ## Lernziele
#
# - `for`-Schleife mit `range()` und über Sequenzen anwenden
# - Verschachtelte Schleifen für 2D-Ausgabe nutzen
# - `while`-Schleife für Eingabeschleifen einsetzen
# - `break` und `continue` gezielt verwenden
#
# **Roter Faden:** Wir geben das Spielfeld als 5×5-Raster aus und bauen die Spielschleife, in der der Spieler wiederholt Koordinaten eingeben kann.

# %% [markdown]
# ---
# ## Block 1: `for`-Schleife (45 min)

# %% [markdown]
# ### `range()` — Zahlenfolgen erzeugen
#
# Die `for`-Schleife wiederholt Code für jedes Element einer Sequenz. Mit `range()` erzeugst du eine Zahlenfolge:
#
# | Aufruf | Erzeugt | Beschreibung |
# |--------|---------|-------------|
# | `range(5)` | 0, 1, 2, 3, 4 | 5 Zahlen, startet bei 0 |
# | `range(1, 6)` | 1, 2, 3, 4, 5 | Von 1 bis 5 (Endwert exklusive) |
#
# **Merke:** Der Endwert ist immer **exklusive** — `range(1, 6)` liefert 1 bis 5, nicht bis 6.

# %%
# range(n) — startet bei 0
for i in range(5):
    print(i)

# %%
# range(start, stop) — Bereich festlegen
for i in range(1, 6):
    print(f"Zeile {i}")

# %% [markdown]
# ### Iteration über Sequenzen
#
# Eine `for`-Schleife kann auch direkt über die Zeichen eines Strings iterieren:

# %%
# Über einen String iterieren
for buchstabe in "ABCDE":
    print(buchstabe)

# %% [markdown]
# ### `enumerate()` — Index und Wert gleichzeitig
#
# Manchmal brauchst du sowohl den **Index** (Position) als auch den **Wert**. Dafür gibt es `enumerate()`:

# %%
# enumerate() liefert Index und Wert als Paar
spalten = "ABCDE"

for index, buchstabe in enumerate(spalten):
    print(f"Spalte {index}: {buchstabe}")

# %% [markdown]
# ### Verschachtelte Schleifen
#
# Für 2D-Ausgaben (z.B. ein Raster) braucht man eine **äußere Schleife** (Zeilen) und eine **innere Schleife** (Spalten):
#
# ```
# Zeile 1: Spalte A, Spalte B, Spalte C, ...
# Zeile 2: Spalte A, Spalte B, Spalte C, ...
# ...
# ```
#
# Die innere Schleife läuft für **jede Iteration** der äußeren Schleife komplett durch.

# %%
# Verschachtelte Schleife: 3×3 Raster
for zeile in range(3):
    for spalte in range(3):
        print("*", end=" ")  # end=" " verhindert den Zeilenumbruch
    print()  # Zeilenumbruch nach jeder Zeile

# %%
# Spielfeld-Kontext: Spaltenköpfe + Raster
# Spaltenköpfe
print("  ", end="")
for buchstabe in "ABCDE":
    print(f" {buchstabe}", end="")
print()  # Zeilenumbruch

# Zeilen mit Zeilennummern
for zeile in range(1, 4):  # nur 3 Zeilen als Demo
    print(f"{zeile} ", end="")
    for spalte in range(5):
        print(" ~", end="")
    print()

# %% [markdown]
# ### `print()` mit `end`-Parameter
#
# Standardmäßig fügt `print()` am Ende einen Zeilenumbruch ein. Mit `end` kann man das ändern:
#
# - `print("Hallo", end=" ")` → kein Zeilenumbruch, stattdessen ein Leerzeichen
# - `print()` → nur ein Zeilenumbruch (nützlich nach einer Zeile im Raster)

# %% [markdown]
# ### 📝 Übung
#
# 1. Gib mit einer `for`-Schleife die Zahlen 1 bis 5 untereinander aus.
# 2. Gib dann mit einer verschachtelten Schleife ein 3×3-Raster aus Sternen (`*`) aus:
#
# ```
# * * *
# * * *
# * * *
# ```

# %%
# Aufgabe 1: Zahlen 1 bis 5
for i in range(1, 6):
    print(i)

# Aufgabe 2: 3×3 Sternraster
for zeile in range(3):
    for spalte in range(3):
        print("*", end=" ")
    print()
# Out:
# 1
# 2
# 3
# 4
# 5
# * * *
# * * *
# * * *

# %% [markdown]
# ---
# ## Block 2: `while`-Schleife (45 min)

# %% [markdown]
# ### `for` vs. `while`
#
# | | `for` | `while` |
# |---|-------|--------|
# | **Wann?** | Anzahl der Durchläufe ist **bekannt** | Abbruchbedingung entscheidet |
# | **Beispiel** | "Gib 5 Zeilen aus" | "Frage bis gültige Eingabe" |
# | **Syntax** | `for x in sequenz:` | `while bedingung:` |

# %%
# while-Schleife: Zähler von 1 bis 5
zaehler = 1

while zaehler <= 5:
    print(f"Durchlauf {zaehler}")
    zaehler = zaehler + 1  # Wichtig: Zähler erhöhen!
# Out:
# Durchlauf 1
# Durchlauf 2
# Durchlauf 3
# Durchlauf 4
# Durchlauf 5

# %% [markdown]
# ### Endlosschleifen erkennen und vermeiden
#
# Eine `while`-Schleife läuft **endlos**, wenn die Bedingung nie `False` wird:
#
# ```python
# # ACHTUNG: Endlosschleife!
# zaehler = 1
# while zaehler <= 5:
#     print(zaehler)
#     # zaehler wird nie erhöht → Bedingung bleibt True
# ```
#
# **Faustregel:** In jeder `while`-Schleife muss sich etwas ändern, das die Bedingung beeinflusst.
#
# Falls eine Endlosschleife passiert: In Jupyter Notebook den **Kernel unterbrechen** (Stopp-Button ⬜).

# %% [markdown]
# ### `break` — Schleife vorzeitig beenden
#
# `break` beendet die Schleife sofort, egal ob die Bedingung noch `True` ist:

# %%
# break: Abbruch wenn gewünschter Wert gefunden
for zahl in range(1, 100):
    if zahl * zahl > 50:
        print(f"{zahl} ist die erste Zahl deren Quadrat > 50 ist")
        break

# %% [markdown]
# ### `continue` — Durchlauf überspringen
#
# `continue` überspringt den Rest des aktuellen Durchlaufs und springt zum nächsten:

# %%
# continue: Ungerade Zahlen überspringen
for zahl in range(1, 11):
    if zahl % 2 != 0:  # % ist der Modulo-Operator (Rest der Division)
        continue
    print(f"{zahl} ist gerade")

# %% [markdown]
# ### Muster: Eingabeschleife mit `while True` + `break`
#
# Ein häufiges Muster: Frage den Nutzer wiederholt, bis eine gültige Eingabe kommt.
#
# ```python
# while True:
#     eingabe = input("Eingabe: ")
#     if eingabe_ist_gueltig:
#         break
#     print("Ungültige Eingabe, versuche es erneut.")
# ```
#
# Das `while True` läuft endlos — der `break` in der `if`-Bedingung ist der einzige Ausgang.

# %%
# Beispiel: Passwort-Eingabe (simuliert mit fester Prüfung)
# Zum Testen: gib "geheim" ein

while True:
    passwort = input("Passwort eingeben: ")
    if passwort == "geheim":
        print("Zugang gewährt!")
        break
    print("Falsches Passwort, nochmal.")

# %% [markdown]
# ### 📝 Übung
#
# Schreibe eine `while`-Schleife, die den Nutzer wiederholt nach einer Zahl fragt, bis er `0` eingibt. Gib am Ende die Summe aller eingegebenen Zahlen aus.
#
# Beispiel:
# ```
# Zahl eingeben (0 zum Beenden): 5
# Zahl eingeben (0 zum Beenden): 3
# Zahl eingeben (0 zum Beenden): 7
# Zahl eingeben (0 zum Beenden): 0
# Summe: 15
# ```

# %%
summe = 0

while True:
    zahl = int(input("Zahl eingeben (0 zum Beenden): "))
    if zahl == 0:
        break
    summe += zahl

print(f"Summe: {summe}")

# %% [markdown]
# ---
# ## Block 3: Praxis — Spielfeld ausgeben + Spielschleife (45 min)
#
# In den folgenden Aufgaben baust du Schritt für Schritt die Spielfeldausgabe und die Spielschleife für *Schiffe versenken*.

# %% [markdown]
# ### Aufgabe 1: Spaltenköpfe
#
# Gib mit einer `for`-Schleife die Buchstaben `A B C D E` in einer Zeile aus (mit Leerzeichen getrennt).
#
# Erwartete Ausgabe:
# ```
#    A B C D E
# ```
#
# <details>
# <summary>💡 Tipp</summary>
#
# Gib zuerst ein paar Leerzeichen aus (`print("  ", end="")`), dann iteriere über `"ABCDE"` und nutze `end=" "`.
# </details>

# %%
# Spaltenköpfe ausgeben
print("  ", end="")
for buchstabe in "ABCDE":
    print(f" {buchstabe}", end="")
print()
# Out:
#    A B C D E

# %% [markdown]
# ### Aufgabe 2: Eine Zeile Wasser
#
# Gib eine Zeile mit Zeilennummer und 5× `~` aus, z.B.:
# ```
# 1  ~ ~ ~ ~ ~
# ```
#
# <details>
# <summary>💡 Tipp</summary>
#
# ```python
# print("1 ", end="")
# for spalte in range(5):
#     print(" ~", end="")
# print()
# ```
# </details>

# %%
print("1 ", end="")
for spalte in range(5):
    print(" ~", end="")
print()
# Out:
# 1  ~ ~ ~ ~ ~

# %% [markdown]
# ### Aufgabe 3: Ganzes 5×5-Raster
#
# Kombiniere Spaltenköpfe und 5 Zeilen mit einer verschachtelten `for`-Schleife zum vollständigen Spielfeld:
#
# ```
#    A B C D E
# 1  ~ ~ ~ ~ ~
# 2  ~ ~ ~ ~ ~
# 3  ~ ~ ~ ~ ~
# 4  ~ ~ ~ ~ ~
# 5  ~ ~ ~ ~ ~
# ```
#
# <details>
# <summary>💡 Tipp</summary>
#
# Nutze `range(1, 6)` für die Zeilen. Für jede Zeile: Zeilennummer ausgeben, dann 5× `~` per innerer Schleife.
# </details>

# %%
# Spaltenköpfe
print("  ", end="")
for buchstabe in "ABCDE":
    print(f" {buchstabe}", end="")
print()

# Zeilen 1–5
for zeile in range(1, 6):
    print(f"{zeile} ", end="")
    for spalte in range(5):
        print(" ~", end="")
    print()
# Out:
#    A B C D E
# 1  ~ ~ ~ ~ ~
# 2  ~ ~ ~ ~ ~
# 3  ~ ~ ~ ~ ~
# 4  ~ ~ ~ ~ ~
# 5  ~ ~ ~ ~ ~

# %% [markdown]
# ### Aufgabe 4: Spielschleife (Grundgerüst)
#
# Schreibe eine `while`-Schleife, die den Spieler 10× nach einer Koordinate fragt und die Eingabe ausgibt. Zähle die Schüsse mit.
#
# Erwartetes Verhalten:
# ```
# Schuss 1/10 - Koordinate eingeben: B3
# Du hast B3 eingegeben.
# Schuss 2/10 - Koordinate eingeben: A1
# Du hast A1 eingegeben.
# ...
# ```
#
# <details>
# <summary>💡 Tipp</summary>
#
# Nutze einen Zähler `schuss = 1` und `while schuss <= 10:`. Vergiss nicht, den Zähler am Ende zu erhöhen.
# </details>

# %%
schuss = 1

while schuss <= 10:
    eingabe = input(f"Schuss {schuss}/10 - Koordinate eingeben: ")
    print(f"Du hast {eingabe} eingegeben.")
    schuss += 1
# Out:
# Du hast  eingegeben.
# Du hast  eingegeben.
# Du hast  eingegeben.
# Du hast  eingegeben.
# Du hast  eingegeben.
# Du hast  eingegeben.
# Du hast  eingegeben.
# Du hast  eingegeben.
# Du hast  eingegeben.
# Du hast  eingegeben.

# %% [markdown]
# ### Aufgabe 5: Spielschleife + Auswertung
#
# Integriere die Schussauswertung aus VL 1 in die Spielschleife:
#
# - Lies eine Koordinate ein und zerlege sie in Buchstabe + Zahl
# - **Ungültige Eingabe:** Gib eine Fehlermeldung aus und überspringe den Rest mit `continue` (Schusszähler **nicht** erhöhen)
# - **Gültige Eingabe:** Prüfe auf Treffer/Wasser, erhöhe den Schusszähler
# - Definiere mindestens 2 Schiffspositionen als Strings
#
# <details>
# <summary>💡 Tipp</summary>
#
# Struktur:
# ```python
# while schuss <= 10:
#     eingabe = input(...)
#     # Validierung
#     if not gueltig:
#         print("Ungültig!")
#         continue  # zurück zum Schleifenanfang, Zähler bleibt
#     # Trefferprüfung
#     ...
#     schuss = schuss + 1  # nur bei gültiger Eingabe
# ```
# </details>

# %%
schiff_1 = "B2"
schiff_2 = "D4"
schuss = 1

while schuss <= 10:
    eingabe = input(f"Schuss {schuss}/10 - Koordinate eingeben: ")

    buchstabe = eingabe[0]
    zahl      = int(eingabe[1]) if len(eingabe) >= 2 else 0

    ist_gueltige_spalte = "A" <= buchstabe <= "E"
    ist_gueltige_zeile  = 1 <= zahl <= 5

    if not (ist_gueltige_spalte and ist_gueltige_zeile):
        print("Ungültige Eingabe!")
        continue

    if eingabe == schiff_1 or eingabe == schiff_2:
        print("Treffer!")
    else:
        print("Wasser!")

    schuss += 1
# Out:
# Wasser!
# Treffer!
# Treffer!
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 8
#       4
#       5 while schuss <= 10:
#       6     eingabe = input(f"Schuss {schuss}/10 - Koordinate eingeben: ")
#       7
# ----> 8     buchstabe = eingabe[0]
#       9     zahl      = int(eingabe[1]) if len(eingabe) >= 2 else 0
#      10
#      11     ist_gueltige_spalte = "A" <= buchstabe <= "E"
#
# IndexError: string index out of range
